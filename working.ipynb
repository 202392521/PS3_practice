# %%
for i in range(1, 11):
    print(f"{i} squared is {i ** 2}")
# This script prints the squares of numbers from 1 to 10.
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16
# 5 squared is 25
# 6 squared is 36
# 7 squared is 49
# 8 squared is 64
# 9 squared is 81
# 10 squared is 100

# %% [markdown]
# Hi I am a mole. Nice to meet you

# %%
class Mole:
    def __init__(self, name):
        self.name = name

    def dig(self):
        print(f"{self.name} is digging a tunnel!")
